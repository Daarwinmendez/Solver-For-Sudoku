# %% [markdown]
# #### Importación de la Librería

# %%
from solver import SudokuSolver as sdks

# %% [markdown]
# ##### Tablero 0 (Moderado)
#
# Cadena :`'.31...2.....629..32..3....7.1..6.37..7.1.5.4..69.3..5.1....3..59..581.....5...98.'`
#
# Visual: \
# ![image.png](attachment:image.png)
#
#
#
# ##### Tablero 1 (Dificil)
# Cadena: `279.........9....7...7.4.3.......8...41..6.........4.....5.2.6....8....4956......`
#
# Visual \
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# #### Declaración de tableros

# %%
tablero_diagonal_str_0 = '.31...2.....629..32..3....7.1..6.37..7.1.5.4..69.3..5.1....3..59..581.....5...98.'
tablero_diagonal_str_1 = '279.........9....7...7.4.3.......8...41..6.........4.....5.2.6....8....4956......'
print(f"Longitud del tablero de prueba: {len(tablero_diagonal_str_0)}")
print(f"Tablero de prueba: {len(tablero_diagonal_str_1)}")
# Out:
# Longitud del tablero de prueba: 81
# Tablero de prueba: 81

# %% [markdown]
# #### Creando instancias de la clase SudokuSolver

# %% [markdown]
# ##### Resoluciones

# %% [markdown]
# ###### Sudoku_0

# %%
# Resolver el Sudoku X
solucion_x_test_0 = solver_x_test_0.resolver(tipo='diagonal')

# Mostrar la solución
print("\n--- Solución Sudoku X 0 ---")
if solucion_x_test_0:
    solver_x_test_0.plot_display(solucion_x_test_0, title="Sudoku X 0 Resuelto", highlight_diagonals=True)
else:
    print("No se pudo resolver el Sudoku X. Revise si es válido o si tiene solución.")
# Out:
# Resolviendo como Sudoku Diagonal...
#
# --- Solución Sudoku X 0 ---

# %% [markdown]
# ###### Parte_2

# %%
# Resolver el Sudoku X
solucion_x_test_1 = solver_x_test_1.resolver(tipo='diagonal')

# Mostrar la solución
print("\n--- Solución Sudoku X 1 ---")
if solucion_x_test_1:
    solver_x_test_1.plot_display(solucion_x_test_1, title="Sudoku X 1 Resuelto", highlight_diagonals=True)
else:
    print("No se pudo resolver el Sudoku X. Revise si es válido o si tiene solución.")
# Out:
# Resolviendo como Sudoku Diagonal...
#
# --- Solución Sudoku X 1 ---

# %% [markdown]
# ### Referencias
#
# [Sudokumania](https://www.sudokumania.com.ar/)
